# %%
using Revise, Pkg
Pkg.activate("../.")
using QuickVega, DataFrames, VegaLite, VegaDatasets, DataStructures
using Distributions, KernelDensity
using Contour
using Setfield

# %%
df = DataFrame(dataset("iris"));

# %%
QuickVega.defaultParameters[:height]
# Out:
# 100

# %% [markdown]
# ## Scatterplot

# %%
x = collect(1:10)
y = float(x.^2)
p = scatterplot(x,y,zcolor=rand(1:2,10),zcolor_type="ordinal")
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark={
#         type="circle"
#     },
#     encoding={
#         x={
#             field="x",
#             type="ordinal"
#         },
#         y={
#             field="y",
#             type="quantitative"
#         },
#         color={
#             field="zcolor",
#             type="ordinal"
#         }
#     }
# )

# %%
df[1:2,:]
# Out:
# 2×5 DataFrame
#  Row │ sepalLength  sepalWidth  petalLength  petalWidth  species
#      │ Float64      Float64     Float64      Float64     String
# ─────┼───────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa
#    2 │         4.9         3.0          1.4         0.2  setosa

# %%
s = scatterplot(df,:petalLength,:petalWidth,zcolor=:species,zsize=:petalLength,size_agg="mean",opacity=0.5)
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark={
#         type="circle",
#         opacity=0.5
#     },
#     encoding={
#         x={
#             field="petalLength",
#             type="quantitative"
#         },
#         y={
#             field="petalWidth",
#             type="quantitative"
#         },
#         color={
#             field="species",
#             type="nominal"
#         },
#         size={
#             field="petalLength",
#             type="quantitative",
#             aggregate="mean"
#         }
#     }
# )

# %% [markdown]
# ## Lineplot

# %%
s = lineplot(x,y)
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark={
#         type="line"
#     },
#     encoding={
#         x={
#             type="ordinal",
#             field="x"
#         },
#         y={
#             type="quantitative",
#             field="y"
#         }
#     }
# )

# %% [markdown]
# ## Scatter + Line

# %%
P = @vlplot() + p + s
# Out:
# @vlplot(
#     layer=[
#         {
#             data={
#                 values=...
#             },
#             mark={
#                 type="circle"
#             },
#             encoding={
#                 x={
#                     field="x",
#                     type="ordinal"
#                 },
#                 y={
#                     field="y",
#                     type="quantitative"
#                 },
#                 color={
#                     field="zcolor",
#                     type="ordinal"
#                 }
#             }
#         },
#         {
#             data={
#                 values=...
#             },
#             mark={
#                 type="line"
#             },
#             encoding={
#                 x={
#                     type="ordinal",
#                     field="x"
#                 },
#                 y={
#                     type="quantitative",
#                     field="y"
#                 }
#             }
#         }
#     ]
# )

# %% [markdown]
# ## Barplot

# %%
x = rand(collect('a':'g'),20)
y = rand(20)
@vlplot() + barplot(x,y,y_agg="mean",color="green",opacity=0.5) + barplot(x,y,y_agg="max",opacity=0.5) + barplot(x,y,y_agg="min",color="red",opacity=0.5)
# Out:
# @vlplot(
#     layer=[
#         {
#             data={
#                 values=...
#             },
#             mark={
#                 type="bar",
#                 opacity=0.5
#             },
#             encoding={
#                 x={
#                     type="nominal",
#                     field="x"
#                 },
#                 y={
#                     type="quantitative",
#                     field="y",
#                     aggregate="mean"
#                 },
#                 color={
#                     value="green"
#                 }
#             }
#         },
#         {
#             data={
#                 values=...
#             },
#             mark={
#                 type="bar",
#                 opacity=0.5
#             },
#             encoding={
#                 x={
#                     type="nominal",
#                     field="x"
#                 },
#                 y={
#                     type="quantitative",
#                     field="y",
#                     aggregate="max"
#                 }
#             }
#         },
#         {
#             data={
#                 values=...
#             },
#             mark={
#                 type="bar",
#                 opacity=0.5
#             },
#             encoding={
#                 x={
#                     type="nominal",
#                     field="x"
#                 },
#                 y={
#                     type="quantitative",
#                     field="y",
#                     aggregate="min"
#                 },
#                 color={
#                     value="red"
#                 }
#             }
#         }
#     ]
# )

# %% [markdown]
# ## Contour Plot

# %%
p = contourplot(df[!,:sepalLength],df[!,:sepalWidth],color_scheme="plasma",mark="area")
# Out:
# @vlplot(
#     data={
#         values=...
#     },
#     mark={
#         type="area"
#     },
#     encoding={
#         x={
#             field="x",
#             type="quantitative"
#         },
#         y={
#             field="y",
#             type="quantitative"
#         },
#         color={
#             field="z",
#             type="quantitative",
#             scale={
#                 scheme="plasma"
#             }
#         },
#         order={
#             field="row",
#             type="quantitative"
#         },
#         detail={
#             field="group",
#             type="quantitative"
#         }
#     }
# )
