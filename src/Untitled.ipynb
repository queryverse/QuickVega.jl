# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = range(0,10)
y = np.random.rand(10)
w = range(0,5)
z = np.random.rand(5)
plt.plot(x,y,label = 'y')
plt.plot(w,z,label = 'z')
plt.legend()
plt.savefig("/home/davi/Desktop/img.png")
